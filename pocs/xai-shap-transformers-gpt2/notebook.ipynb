# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import shap
from IPython.display import display

tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model = AutoModelForCausalLM.from_pretrained("gpt2").cpu()

model.config.is_decoder = True
model.config.task_specific_params["text-generation"] = {
    "do_sample": True,
    "max_length": 50,
    "temperature": 0.7,
    "top_k": 50,
    "no_repeat_ngram_size": 2,
}

s = ["I enjoy walking with my cute cats"]
explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(s)
shap.plots.text(shap_values)
# Out:
# /home/diego/.local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# /home/diego/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /home/diego/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/diego/.local/lib/python3.10/site-packages/beartype/_util/module/utilmodimport.py:156: BeartypeModuleUnimportableWarning: Ignoring module "onnx" importation exception:
# 	ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/home/diego/.local/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
#   warn(
# /home/diego/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/diego/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 2024-05-31 03:12:30.141895: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-31 03:12:31.529673: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diego/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2024-05-31 03:12:31.529932: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diego/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2024-05-31 03:12:31.529950: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /home/diego/.local/lib/python3.10/site-packages/transformers/generation/utils.py:1141: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# PartitionExplainer explainer: 2it [00:11, 11.60s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_einaqkvslkbnjvicpbne = '_tp_einaqkvslkbnjvicpbne_output_0';
#     document._zoom_einaqkvslkbnjvicpbne = undefined;
#     function _output_onclick_einaqkvslkbnjvicpbne(i) {
#         var next_id = undefined;
#
#         if (document._zoom_einaqkvslkbnjvicpbne !== undefined) {
#             document.getElementById(document._zoom_einaqkvslkbnjvicpbne+ '_zoom').style.display = 'none';
#
#             if (document._zoom_einaqkvslkbnjvicpbne === '_tp_einaqkvslkbnjvicpbne_output_' + i) {
#                 document.getElementById(document._zoom_einaqkvslkbnjvicpbne).style.display = 'block';
#                 document.getElementById(document._zoom_einaqkvslkbnjvicpbne+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_einaqkvslkbnjvicpbne).style.display = 'none';
#                 document.getElementById(document._zoom_einaqkvslkbnjvicpbne+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_einaqkvslkbnjvicpbne !== '_tp_einaqkvslkbnjvicpbne_output_' + i) {
#             next_id = '_tp_einaqkvslkbnjvicpbne_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_einaqkvslkbnjvicpbne = next_id;
#     }
#     function _output_onmouseover_einaqkvslkbnjvicpbne(i, el) {
#         if (document._zoom_einaqkvslkbnjvicpbne !== undefined) { return; }
#         if (document._hover_einaqkvslkbnjvicpbne !== undefined) {
#             document.getElementById(document._hover_einaqkvslkbnjvicpbne + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_einaqkvslkbnjvicpbne).style.display = 'none';
#         }
#         document.getElementById('_tp_einaqkvslkbnjvicpbne_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_einaqkvslkbnjvicpbne = '_tp_einaqkvslkbnjvicpbne_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.4482075658546247); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_0_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(0)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(0, this);">,</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.46397306397306387); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_1_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(1)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(1, this);">but</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.282669835611012); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_2_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(2)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(2, this);">I</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6452762923351159); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_3_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(3)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(3, this);">'m</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.36938007526242816); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_4_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(4)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(4, this);">not</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.527035056446821); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_5_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(5)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(5, this);">sure</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.3299663299663299); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_6_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(6)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(6, this);">if</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.14866310160427798); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_7_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(7)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(7, this);">I</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6768072885719945); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_8_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(8)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(8, this);">can</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_9_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(9)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(9, this);">do</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.10924935630817977); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_10_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(10)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(10, this);">it</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.6610417904535552); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_11_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(11)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(11, this);">with</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.4482075658546247); border-radius: 3px; padding: 0px" id="_tp_einaqkvslkbnjvicpbne_output_12_name"
#     onclick="_output_onclick_einaqkvslkbnjvicpbne(12)"
#     onmouseover="_output_onmouseover_einaqkvslkbnjvicpbne(12, this);">my</div><br><br><div id='_tp_einaqkvslkbnjvicpbne_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="45.67024534729774%" y1="33" x2="45.67024534729774%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="45.67024534729774%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="32.68411904145499%" y1="33" x2="32.68411904145499%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.68411904145499%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="19.697992735612246%" y1="33" x2="19.697992735612246%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.697992735612246%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="58.65637165314048%" y1="33" x2="58.65637165314048%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.65637165314048%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="71.64249795898323%" y1="33" x2="71.64249795898323%" y2="37" style="stroke:rgb(150,150
